# %% [markdown]
# # REGRESSION PLOT
# - It shows the relationship between two variables
# - To keep in mind:
# - 1. vertical axis = dependent
#   2. horizontal axis = independent

# %%
import seaborn as sns
flights = sns.load_dataset("flights")
print(flights)
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.regplot(x= "year", y = "passengers", data = flights)

import matplotlib.pyplot as plt
plt.ylim(0,500)
# Out:
# (0.0, 500.0)
